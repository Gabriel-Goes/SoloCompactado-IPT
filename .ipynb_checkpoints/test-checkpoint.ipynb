# %%
.libPaths("˜/R/library")
library(soilphysics)
# Out:
# Error in library(soilphysics): não há nenhum pacote chamado ‘soilphysics’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
  .libPaths("~/R/library")
    3   library(soilphysics)
    4
    5   Célula 2 — Tensão aplicada pelo pneu (TASC + Boussinesq/Froehlich)
    6   profundidades <- c(0.10, 0.20, 0.30, 0.40, 0.50, 0.60)
    7
    8   stress <- stressTraffic(
    9    │inflation.pressure = 150,       # pressão de inflação (kPa) = 1.5 bar
   10    │recommended.pressure = 150,     # pressão recomendada (kPa)
   11    │tyre.diameter = 1.42,           # diâmetro do pneu (m)
   12    │tyre.width = 0.60,              # largura do pneu (m)
   13    │wheel.load = 5000,              # carga na roda (kg) = 5 toneladas
   14    │conc.factor = c(4,4,4,5,5,5),  # xi por camada (4=úmido, 5=seco)
   15    │layers = profundidades
   16   )
   17
   18   cat("=== ÁREA DE CONTATO ===\n")
   19   print(stress$Area)
   20
   21   cat("\n=== CARGAS ESTIMADAS ===\n")
   22   print(stress$Loads)
   23
   24   cat("\n=== TENSÃO VERTICAL POR PROFUNDIDADE ===\n")
